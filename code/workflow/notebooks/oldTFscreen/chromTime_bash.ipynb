# %%
cd /c/groups/sanjana_lab/cdai/TFscreen/atac/chrometime/ChromTime && ls
# Out:
# call_boundary_dynamics.py    ChromTime.py   LICENSE       utils.c
# call_boundary_dynamics.pyc   constants.py   Makefile      utils.py
# C_call_boundary_dynamics.c   constants.pyc  optimize.py   utils.pyc
# C_call_boundary_dynamics.o   example        optimize.pyc
# C_call_boundary_dynamics.so  genomes        README.md

# %%
module load chromtime && module list
# Out:
# Currently Loaded Modulefiles:
#   1) htslib/1.9        3) bedtools/2.25.0   5) chromtime/1.0
#   2) samtools/1.9      4) jupyter3/4.1

# %%
which chromtime
# Out:
# /nfs/sw/chromtime/chromtime-1.0.0/chromtime

# %%
cd

# %%
cd example/ && python ../ChromTime.py -i input_order -o t_cell_development.H3K4ME2 -p t_cell_development.H3K4ME2 -t 12 -g mm9
# Out:
# [2019-12-11 21:18:25] Reading order file: input_order
# [2019-12-11 21:18:25] Command line: ../ChromTime.py -i input_order -o t_cell_development.H3K4ME2 -p t_cell_development.H3K4ME2 -t 12 -g mm9
# [2019-12-11 21:18:25] Options:
#  {'aligned_fnames': None,
#  'bin_size': 200,
#  'broad': False,
#  'control_fnames': None,
#  'data_fname': None,
#  'fdr_for_decoding': 0.05,
#  'genome': 'mm9',
#  'keep_fixed_priors': False,
#  'merge_peaks': False,
#  'min_dynamic_prior': 0.0,
#  'min_expected_reads': 1,
#  'min_gap': 600,
#  'mode': None,
#  'model_fname': None,
#  'n_threads': 12,
#  'n_training_examples': 10000,
#  'order_fname': 'input_order',
#  'out_dir': 't_cell_development.H3K4ME2',
#  'output_empty_blocks': False,
#  'output_signal_files': False,
#  'p_value_extend': 0.15,
#  'prefix': 't_cell_development.H3K4ME2',
#  'q_value_seed': 0.05,
#  'shift': 100,
#  'skip_training': False,
#  'use_broad_window_for_background': False}
# ...

# %%
ls t_cell_development.H3K4ME2/*ChromTime_full_output.bed.gz
# Out:
# t_cell_development.H3K4ME2/t_cell_development.H3K4ME2.ChromTime_full_output.bed.gz

# %%
zcat t_cell_development.H3K4ME2/t_cell_development.H3K4ME2.ChromTime_full_output.bed.gz | head -1 | cut -f 10
# Out:
# posteriors:{'left_boundary': [{'S': 0.9992304288998902, 'E': 0.0007115548724106199, 'C': 5.801622769896309e-05}, {'S': 0.48127508581147577, 'E': 0.45092263410388544, 'C': 0.06780228008463873}, {'S': 0.7524396037537043, 'E': 0.20959897268429137, 'C': 0.03796142356200427}, {'S': 0.46222960819340847, 'E': 0.5372937207802614, 'C': 0.000476671026330108}], 'right_boundary': [{'S': 0.9992032570020434, 'E': 0.0007417361107159172, 'C': 5.5006887240538514e-05}, {'S': 0.49710784115075324, 'E': 0.43511124495727066, 'C': 0.06778091389197609}, {'S': 0.928516907173811, 'E': 0.06455964422666419, 'C': 0.006923448599524792}, {'S': 0.9249417400483055, 'E': 0.07441189346683885, 'C': 0.0006463664848554388}]}
#
# gzip: stdout: Broken pipe
